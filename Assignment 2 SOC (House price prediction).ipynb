# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('Housing Price data set.csv')

# %%
df.head()
# Out:
#    Unnamed: 0    price  lotsize  bedrooms  bathrms  stories driveway recroom  \
# 0           1  42000.0     5850         3        1        2      yes      no
# 1           2  38500.0     4000         2        1        1      yes      no
# 2           3  49500.0     3060         3        1        1      yes      no
# 3           4  60500.0     6650         3        1        2      yes     yes
# 4           5  61000.0     6360         2        1        1      yes      no
#
#   fullbase gashw airco  garagepl prefarea
# 0      yes    no    no         1       no
# 1       no    no    no         0       no
# 2       no    no    no         0       no
# 3       no    no    no         0       no
# 4       no    no    no         0       no

# %%
df.tail(10)
# Out:
#      Unnamed: 0     price  lotsize  bedrooms  bathrms  stories driveway  \
# 536         537   82500.0     6000         3        2        4      yes
# 537         538   83000.0     4800         3        1        3      yes
# 538         539   84000.0     6500         3        2        3      yes
# 539         540   85000.0     7320         4        2        2      yes
# 540         541   85000.0     6525         3        2        4      yes
# 541         542   91500.0     4800         3        2        4      yes
# 542         543   94000.0     6000         3        2        4      yes
# 543         544  103000.0     6000         3        2        4      yes
# 544         545  105000.0     6000         3        2        2      yes
# 545         546  105000.0     6000         3        1        2      yes
#
#     recroom fullbase gashw airco  garagepl prefarea
# 536      no       no    no   yes         0       no
# 537      no       no    no   yes         0       no
# ...

# %%
df = df.drop(['Unnamed: 0','driveway','fullbase','prefarea', 'gashw', 'garagepl'], axis='columns')

# %%
df.head(10)
# Out:
#      price  lotsize  bedrooms  bathrms  stories recroom airco
# 0  42000.0     5850         3        1        2      no    no
# 1  38500.0     4000         2        1        1      no    no
# 2  49500.0     3060         3        1        1      no    no
# 3  60500.0     6650         3        1        2     yes    no
# 4  61000.0     6360         2        1        1      no    no
# 5  66000.0     4160         3        1        1     yes   yes
# 6  66000.0     3880         3        2        2      no    no
# 7  69000.0     4160         3        1        3      no    no
# 8  83800.0     4800         3        1        1     yes    no
# 9  88500.0     5500         3        2        4     yes   yes

# %%
from sklearn import linear_model

# %%
reg= linear_model.LinearRegression()

# %%
reg.fit(df[['lotsize','bedrooms','bathrms','stories']], df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[4100, 2, 1, 1]])
# Out:
# C:\Users\Avani Gala\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([48639.36122326])

# %%
reg.predict([[4100, 3, 1, 3]])
# Out:
# C:\Users\Avani Gala\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([66733.76901849])

# %%
dummies= pd.get_dummies(df.recroom, df.airco)

# %%
dummies.head(10)
# Out:
#    0       no\n1       no\n2       no\n3       no\n4       no\n      ... \n541    yes\n542    yes\n543    yes\n544    yes\n545    yes\nName: airco, Length: 546, dtype: object_no  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                              False
# 4                                               True
# 5                                              False
# 6                                               True
# 7                                               True
# 8                                              False
# 9                                              False
#
#    0       no\n1       no\n2       no\n3       no\n4       no\n      ... \n541    yes\n542    yes\n543    yes\n544    yes\n545    yes\nName: airco, Length: 546, dtype: object_yes
# 0                                              False
# ...

# %%
merged= pd.concat([df,dummies],axis='columns')

# %%
merged
# Out:
#         price  lotsize  bedrooms  bathrms  stories recroom airco  \
# 0     42000.0     5850         3        1        2      no    no
# 1     38500.0     4000         2        1        1      no    no
# 2     49500.0     3060         3        1        1      no    no
# 3     60500.0     6650         3        1        2     yes    no
# 4     61000.0     6360         2        1        1      no    no
# ..        ...      ...       ...      ...      ...     ...   ...
# 541   91500.0     4800         3        2        4     yes   yes
# 542   94000.0     6000         3        2        4      no   yes
# 543  103000.0     6000         3        2        4     yes   yes
# 544  105000.0     6000         3        2        2     yes   yes
# 545  105000.0     6000         3        1        2      no   yes
#
#      0       no\n1       no\n2       no\n3       no\n4       no\n      ... \n541    yes\n542    yes\n543    yes\n544    yes\n545    yes\nName: airco, Length: 546, dtype: object_no  \
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
x = merged.drop('price', axis='columns')

# %%
x
# Out:
#      lotsize  bedrooms  bathrms  stories recroom airco  \
# 0       5850         3        1        2      no    no
# 1       4000         2        1        1      no    no
# 2       3060         3        1        1      no    no
# 3       6650         3        1        2     yes    no
# 4       6360         2        1        1      no    no
# ..       ...       ...      ...      ...     ...   ...
# 541     4800         3        2        4     yes   yes
# 542     6000         3        2        4      no   yes
# 543     6000         3        2        4     yes   yes
# 544     6000         3        2        2     yes   yes
# 545     6000         3        1        2      no   yes
#
#      0       no\n1       no\n2       no\n3       no\n4       no\n      ... \n541    yes\n542    yes\n543    yes\n544    yes\n545    yes\nName: airco, Length: 546, dtype: object_no  \
# 0                                                 True
# 1                                                 True
# ...

# %%
y=merged.price
y
# Out:
# 0       42000.0
# 1       38500.0
# 2       49500.0
# 3       60500.0
# 4       61000.0
#          ...
# 541     91500.0
# 542     94000.0
# 543    103000.0
# 544    105000.0
# 545    105000.0
# Name: price, Length: 546, dtype: float64

# %%
model.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 model.fit(x,y)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_base.py:609, in LinearRegression.fit(self, X, y, sample_weight)
#     605 n_jobs_ = self.n_jobs
#     607 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 609 X, y = self._validate_data(
#     610     X,
#     611     y,
# ...
